# %% [markdown]
# <a href="https://colab.research.google.com/github/sarthak-geek/SIH-2026/blob/main/Dataaset_observation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import matplotlib.patches as patches
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/SIH_dataset/dataset/train'

# %%
labels = pd.read_csv(os.path.join(path,'_annotations.csv'))

# %%
print(labels.shape)
labels.head()
# Out:
# (1256, 8)
#                                             filename  width  height    class  \
# 0  img-561_jpg.rf.00e55aff1b67a607a6631ac6a05bf7a...    400     300  pothole
# 1  img-561_jpg.rf.00e55aff1b67a607a6631ac6a05bf7a...    400     300  pothole
# 2  img-561_jpg.rf.00e55aff1b67a607a6631ac6a05bf7a...    400     300  pothole
# 3  img-561_jpg.rf.00e55aff1b67a607a6631ac6a05bf7a...    400     300  pothole
# 4  img-561_jpg.rf.00e55aff1b67a607a6631ac6a05bf7a...    400     300  pothole
#
#    xmin  ymin  xmax  ymax
# 0   175    37   211    51
# 1   189     4   246    24
# 2   278     0   399   160
# 3    19    86   297   190
# 4    60   200   178   299

# %%
images = []
for filename in os.listdir(path):
  if filename == '_annotations.csv':
    continue
  img = Image.open(os.path.join(path, filename))
  images.append([filename, img])

# %%
i= 0
img_name = images[i][0]
img = images[i][1]
fig, ax = plt.subplots()
potholes = labels[labels['filename'] == img_name]
plt.imshow(img)

print(img.size)
potholes
for _, row in potholes.iterrows():
  xmin = row['xmin']
  xmax = row['xmax']
  ymin = row['ymin']
  ymax = row['ymax']
  w = row['width']
  h = row['height']
  rect = patches.Rectangle((xmin,ymin), (xmax-xmin), (ymax-ymin),edgecolor='red',linewidth=2,alpha=0.4)
  ax.add_patch(rect)
plt.show()
# Out:
# (720, 720)

# %%
print(len(labels['filename'].unique()), len(images))
# Out:
# 465 465
