# %% [markdown]
# <a href="https://colab.research.google.com/github/sarthak-geek/SIH-2026/blob/main/Training_YOLO11n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install YOLO
# !pip install -U ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 51.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 8.7 MB/s eta 0:00:00
# ...

# %%
# Import
from ultralytics import YOLO
import os
from google.colab import drive
# Out:
# Creating new Ultralytics Settings v0.0.8 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/usage/settings.

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Dataset
dataset_path = "/content/drive/MyDrive/SIH_dataset/yolo_dataset"
yaml_path = f"{dataset_path}/data.yaml"
# Load pretrained YOLO11 Nano
model = YOLO("yolo11n.pt")

# %%
# Train
results = model.train(
    data=yaml_path,
    epochs=50,
    imgsz=640,
    batch=16,
    device=0,
    project="/content/drive/MyDrive/SIH_dataset/yolo_training",
    name="pothole_yolo11n"
)
# Out:
# Ultralytics 8.4.155 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
os.listdir('/content/drive/MyDrive/SIH_dataset/yolo_training/pothole_yolo11n')
# Out:
# ['weights',
#  'args.yaml',
#  'labels.jpg',
#  'train_batch0.jpg',
#  'train_batch1.jpg',
#  'train_batch2.jpg',
#  'results.csv',
#  'train_batch1200.jpg',
#  'train_batch1201.jpg',
#  'train_batch1202.jpg',
#  'val_batch0_labels.jpg',
#  'val_batch0_pred.jpg',
#  'val_batch1_labels.jpg',
#  'val_batch1_pred.jpg',
#  'val_batch2_labels.jpg',
#  'val_batch2_pred.jpg',
#  'BoxPR_curve.png',
#  'BoxF1_curve.png',
#  'BoxP_curve.png',
#  'BoxR_curve.png',
#  'confusion_matrix_normalized.png',
#  'confusion_matrix.png',
#  'results.png']
